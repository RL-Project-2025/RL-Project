# %%
import os
import sys
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Jupyter Magic to make plots show up inline
# %matplotlib inline

import gymnasium as gym
import gym4real
from gymnasium import spaces
from gym4real.envs.wds.utils import parameter_generator
from stable_baselines3 import DQN, A2C
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor, VecNormalize
from gymnasium.wrappers import TimeLimit

import wntr
import wntr.sim
# Out:
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/wntr/epanet/toolkit.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_filename

# %%
config_path = os.path.join(os.getcwd(), "gym4real", "envs", "wds", "world_anytown.yaml")

base_params = parameter_generator(
    hydraulic_step=3600,
    duration=3600 * 24 * 7,
    seed=42,
    world_options=config_path)

base_params['demand_moving_average'] = False  # Turn off SMA 
base_params['demand_exp_moving_average'] = True  # Turn on EMA

# %%
def make_env_tl_wrapper():
    env = gym.make('gym4real/wds-v0', settings=base_params)
    env = TimeLimit(env, max_episode_steps=250)  # Give it 250 steps to finish 168 hours
    
    return env

# %%
# CREATE TRAINING ENVIRONMENT
train_env = DummyVecEnv([make_env_tl_wrapper])
train_env = VecMonitor(train_env)
MODEL_NAME = "DQN_WDSEnv_TL_Wrapper"

print("🧠 Initializing DQN Agent...")
model = DQN(
    "MlpPolicy", 
    train_env,
    device='cpu',
    verbose=1,
    tensorboard_log="./wds_logs/")

print(f"Training {MODEL_NAME}...")
model.learn(total_timesteps=150000, tb_log_name="dqn_wds_run_tl_wrapper")
print("✅ Training Complete.")

# Save the model
model.save(MODEL_NAME)
# Out:
# 🧠 Initializing DQN Agent...
# Using cpu device
# Training DQN_WDSEnv_TL_Wrapper...
# Resetting the environment...
# Logging to ./wds_logs/dqn_wds_run_tl_wrapper_1
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 34       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 896      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 198      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 34       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 1759     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 414      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 34       |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 2652     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 637      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 34       |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 3534     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0206   |
# |    n_updates        | 858      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 34       |
# |    time_elapsed     | 128      |
# |    total_timesteps  | 4429     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 1082     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.664    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 34       |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 5308     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 1301     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.605    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 34       |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 6231     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0338   |
# |    n_updates        | 1532     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 34       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 7110     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 1752     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 34       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 8021     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 1980     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 34       |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 8891     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 2197     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.381    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 34       |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 9778     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 2419     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 34       |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 10575    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0121   |
# |    n_updates        | 2618     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 154      |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 34       |
# |    time_elapsed     | 331      |
# |    total_timesteps  | 11373    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 2818     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.23     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 34       |
# |    time_elapsed     | 353      |
# |    total_timesteps  | 12157    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0461   |
# |    n_updates        | 3014     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 149      |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 34       |
# |    time_elapsed     | 376      |
# |    total_timesteps  | 12935    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0225   |
# |    n_updates        | 3208     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 147      |
# |    exploration_rate | 0.132    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 34       |
# |    time_elapsed     | 399      |
# |    total_timesteps  | 13710    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 3402     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.0829   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 34       |
# |    time_elapsed     | 421      |
# |    total_timesteps  | 14481    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0212   |
# |    n_updates        | 3595     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 212      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 34       |
# |    time_elapsed     | 443      |
# |    total_timesteps  | 15235    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0164   |
# |    n_updates        | 3783     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 210      |
# |    ep_rew_mean      | 143      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 34       |
# |    time_elapsed     | 465      |
# |    total_timesteps  | 15989    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 3972     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 209      |
# |    ep_rew_mean      | 141      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 34       |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 16721    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 4155     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 208      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 34       |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 17457    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.13     |
# |    n_updates        | 4339     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 207      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 34       |
# |    time_elapsed     | 529      |
# |    total_timesteps  | 18190    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 4522     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 206      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 34       |
# |    time_elapsed     | 551      |
# |    total_timesteps  | 18942    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 4710     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 34       |
# |    time_elapsed     | 573      |
# |    total_timesteps  | 19709    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0613   |
# |    n_updates        | 4902     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 205      |
# |    ep_rew_mean      | 138      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 34       |
# |    time_elapsed     | 595      |
# |    total_timesteps  | 20488    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0444   |
# |    n_updates        | 5096     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 204      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 34       |
# |    time_elapsed     | 618      |
# |    total_timesteps  | 21257    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 5289     |
# ----------------------------------
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 203      |
# |    ep_rew_mean      | 135      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 34       |
# |    time_elapsed     | 640      |
# |    total_timesteps  | 22013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0399   |
# |    n_updates        | 5478     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 34       |
# |    time_elapsed     | 662      |
# |    total_timesteps  | 22791    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.039    |
# |    n_updates        | 5672     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 201      |
# |    ep_rew_mean      | 134      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 34       |
# |    time_elapsed     | 686      |
# |    total_timesteps  | 23596    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 5873     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 34       |
# |    time_elapsed     | 708      |
# |    total_timesteps  | 24374    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 6068     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 34       |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 25135    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0145   |
# |    n_updates        | 6258     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 34       |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 25908    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 6451     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 34       |
# |    time_elapsed     | 776      |
# |    total_timesteps  | 26680    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0171   |
# |    n_updates        | 6644     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 34       |
# |    time_elapsed     | 798      |
# |    total_timesteps  | 27421    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 6830     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 34       |
# |    time_elapsed     | 820      |
# |    total_timesteps  | 28208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00939  |
# |    n_updates        | 7026     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 34       |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 28971    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0489   |
# |    n_updates        | 7217     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 126      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 34       |
# |    time_elapsed     | 865      |
# |    total_timesteps  | 29752    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0385   |
# |    n_updates        | 7412     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 127      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 34       |
# |    time_elapsed     | 889      |
# |    total_timesteps  | 30553    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 7613     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 128      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 34       |
# |    time_elapsed     | 911      |
# |    total_timesteps  | 31333    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.055    |
# |    n_updates        | 7808     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 130      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 34       |
# |    time_elapsed     | 934      |
# |    total_timesteps  | 32112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 8002     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 34       |
# |    time_elapsed     | 957      |
# |    total_timesteps  | 32893    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0403   |
# |    n_updates        | 8198     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 131      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 34       |
# |    time_elapsed     | 980      |
# |    total_timesteps  | 33668    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0419   |
# |    n_updates        | 8391     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 192      |
# |    ep_rew_mean      | 132      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 34       |
# |    time_elapsed     | 1003     |
# |    total_timesteps  | 34469    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00941  |
# |    n_updates        | 8592     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 34       |
# |    time_elapsed     | 1026     |
# |    total_timesteps  | 35254    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 8788     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 136      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 34       |
# |    time_elapsed     | 1049     |
# |    total_timesteps  | 36040    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 8984     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 137      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 34       |
# |    time_elapsed     | 1072     |
# |    total_timesteps  | 36834    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0228   |
# |    n_updates        | 9183     |
# ----------------------------------
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 34       |
# |    time_elapsed     | 1095     |
# |    total_timesteps  | 37615    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 9378     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 139      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 34       |
# |    time_elapsed     | 1117     |
# |    total_timesteps  | 38377    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 9569     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 34       |
# |    time_elapsed     | 1140     |
# |    total_timesteps  | 39165    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 9766     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 34       |
# |    time_elapsed     | 1163     |
# |    total_timesteps  | 39957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.137    |
# |    n_updates        | 9964     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 142      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 34       |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 40793    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0313   |
# |    n_updates        | 10173    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 144      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 34       |
# |    time_elapsed     | 1210     |
# |    total_timesteps  | 41591    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0421   |
# |    n_updates        | 10372    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 34       |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 42389    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0154   |
# |    n_updates        | 10572    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 34       |
# |    time_elapsed     | 1257     |
# |    total_timesteps  | 43208    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 10776    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 148      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 34       |
# |    time_elapsed     | 1280     |
# |    total_timesteps  | 43997    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 10974    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 150      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 34       |
# |    time_elapsed     | 1303     |
# |    total_timesteps  | 44773    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0113   |
# |    n_updates        | 11168    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 151      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 34       |
# |    time_elapsed     | 1326     |
# |    total_timesteps  | 45555    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0208   |
# |    n_updates        | 11363    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 152      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 34       |
# |    time_elapsed     | 1349     |
# |    total_timesteps  | 46336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 11558    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 155      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 34       |
# |    time_elapsed     | 1372     |
# |    total_timesteps  | 47126    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0479   |
# |    n_updates        | 11756    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 34       |
# |    time_elapsed     | 1395     |
# |    total_timesteps  | 47912    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 11952    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 34       |
# |    time_elapsed     | 1417     |
# |    total_timesteps  | 48677    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 12144    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 34       |
# |    time_elapsed     | 1439     |
# |    total_timesteps  | 49448    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0108   |
# |    n_updates        | 12336    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 34       |
# |    time_elapsed     | 1463     |
# |    total_timesteps  | 50240    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0207   |
# |    n_updates        | 12534    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 34       |
# |    time_elapsed     | 1486     |
# |    total_timesteps  | 51034    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0416   |
# |    n_updates        | 12733    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 161      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 34       |
# |    time_elapsed     | 1509     |
# |    total_timesteps  | 51829    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0134   |
# |    n_updates        | 12932    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 34       |
# |    time_elapsed     | 1531     |
# |    total_timesteps  | 52611    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0192   |
# |    n_updates        | 13127    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 34       |
# |    time_elapsed     | 1554     |
# |    total_timesteps  | 53375    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0281   |
# |    n_updates        | 13318    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 34       |
# |    time_elapsed     | 1577     |
# |    total_timesteps  | 54162    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 13515    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 34       |
# |    time_elapsed     | 1598     |
# |    total_timesteps  | 54910    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 13702    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 34       |
# |    time_elapsed     | 1621     |
# |    total_timesteps  | 55686    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0242   |
# |    n_updates        | 13896    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 34       |
# |    time_elapsed     | 1644     |
# |    total_timesteps  | 56464    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 14090    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 34       |
# |    time_elapsed     | 1665     |
# |    total_timesteps  | 57204    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0189   |
# |    n_updates        | 14275    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# ...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 193      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 34       |
# |    time_elapsed     | 3835     |
# |    total_timesteps  | 131038   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 32734    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 34       |
# |    time_elapsed     | 3858     |
# |    total_timesteps  | 131823   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 32930    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 34       |
# |    time_elapsed     | 3881     |
# |    total_timesteps  | 132619   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 33129    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 34       |
# |    time_elapsed     | 3905     |
# |    total_timesteps  | 133434   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0136   |
# |    n_updates        | 33333    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 34       |
# |    time_elapsed     | 3934     |
# |    total_timesteps  | 134240   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 33534    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 34       |
# |    time_elapsed     | 3962     |
# |    total_timesteps  | 135022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 33730    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 31       |
# |    time_elapsed     | 4300     |
# |    total_timesteps  | 135787   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0084   |
# |    n_updates        | 33921    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 31       |
# |    time_elapsed     | 4322     |
# |    total_timesteps  | 136565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0276   |
# |    n_updates        | 34116    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 31       |
# |    time_elapsed     | 4346     |
# |    total_timesteps  | 137360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 34314    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 31       |
# |    time_elapsed     | 4368     |
# |    total_timesteps  | 138120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0106   |
# |    n_updates        | 34504    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 31       |
# |    time_elapsed     | 4391     |
# |    total_timesteps  | 138899   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00659  |
# |    n_updates        | 34699    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 31       |
# |    time_elapsed     | 4413     |
# |    total_timesteps  | 139678   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0259   |
# |    n_updates        | 34894    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 31       |
# |    time_elapsed     | 4437     |
# |    total_timesteps  | 140488   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 35096    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 196      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 31       |
# |    time_elapsed     | 4459     |
# |    total_timesteps  | 141238   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0153   |
# |    n_updates        | 35284    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 31       |
# |    time_elapsed     | 4482     |
# |    total_timesteps  | 142020   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0294   |
# |    n_updates        | 35479    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 31       |
# |    time_elapsed     | 4504     |
# |    total_timesteps  | 142784   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0392   |
# |    n_updates        | 35670    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 168      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 31       |
# |    time_elapsed     | 4526     |
# |    total_timesteps  | 143543   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0209   |
# |    n_updates        | 35860    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 31       |
# |    time_elapsed     | 4548     |
# |    total_timesteps  | 144299   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00479  |
# |    n_updates        | 36049    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 31       |
# |    time_elapsed     | 4570     |
# |    total_timesteps  | 145049   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 36237    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 31       |
# |    time_elapsed     | 4592     |
# |    total_timesteps  | 145801   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0224   |
# |    n_updates        | 36425    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 31       |
# |    time_elapsed     | 4615     |
# |    total_timesteps  | 146582   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00949  |
# |    n_updates        | 36620    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 195      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 30       |
# |    time_elapsed     | 4796     |
# |    total_timesteps  | 147336   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 36808    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 30       |
# |    time_elapsed     | 4818     |
# |    total_timesteps  | 148090   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 36997    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 30       |
# |    time_elapsed     | 4839     |
# |    total_timesteps  | 148827   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 37181    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 194      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 30       |
# |    time_elapsed     | 4862     |
# |    total_timesteps  | 149594   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0185   |
# |    n_updates        | 37373    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# ✅ Training Complete.

# %%
# CREATE TRAINING ENVIRONMENT
train_env = DummyVecEnv([make_env_tl_wrapper])
train_env = VecMonitor(train_env)
MODEL_NAME = "A2C_WDSEnv_TL_Wrapper"

print("🧠 Initializing A2C Agent...")
model = A2C(
    "MlpPolicy", 
    train_env, 
    learning_rate=1e-4,
    device="cpu", 
    verbose=1,
    tensorboard_log="./wds_logs/")

print(f"Training {MODEL_NAME}...")
model.learn(total_timesteps=150000, tb_log_name="a2c_wds_run_tl_wrapper") # Increase this for better results
print("✅ Training Complete.")

# Save the model
model.save(MODEL_NAME)
# Out:
# 🧠 Initializing A2C Agent...
# Using cpu device
# Training A2C_WDSEnv_TL_Wrapper...
# Resetting the environment...
# Logging to ./wds_logs/a2c_wds_run_tl_wrapper_1
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 100      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0103   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 3.38     |
# |    value_loss         | 6.93     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 153      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 200      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -30.4    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | 7.13     |
# |    value_loss         | 34.3     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 156      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 300      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 7.11e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0127   |
# |    value_loss         | 0.0785   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 400      |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -1.5e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.99     |
# |    value_loss         | 2.37     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 226       |
# |    ep_rew_mean        | 153       |
# | time/                 |           |
# |    fps                | 34        |
# |    iterations         | 500       |
# |    time_elapsed       | 72        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -9.78e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 499       |
# |    policy_loss        | 3.02      |
# |    value_loss         | 6.44      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 600      |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.000176 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 599      |
# |    policy_loss        | 3.11     |
# |    value_loss         | 6.86     |
# ------------------------------------
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 226       |
# |    ep_rew_mean        | 155       |
# | time/                 |           |
# |    fps                | 34        |
# |    iterations         | 700       |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -0.000972 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.66      |
# |    value_loss         | 1.34      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 800      |
# |    time_elapsed       | 117      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -23.5    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 799      |
# |    policy_loss        | 6.11     |
# |    value_loss         | 49.6     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 157      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 900      |
# |    time_elapsed       | 131      |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 4.82e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 899      |
# |    policy_loss        | 3.18     |
# |    value_loss         | 6.36     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 157      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1000     |
# |    time_elapsed       | 146      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.00121 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.0452  |
# |    value_loss         | 0.042    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 223       |
# |    ep_rew_mean        | 158       |
# | time/                 |           |
# |    fps                | 34        |
# |    iterations         | 1100      |
# |    time_elapsed       | 160       |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -0.000246 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1099      |
# |    policy_loss        | 3.16      |
# |    value_loss         | 6.06      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1200     |
# |    time_elapsed       | 175      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -8.7e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1199     |
# |    policy_loss        | 2.16     |
# |    value_loss         | 2.78     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1300     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 6.23e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1299     |
# |    policy_loss        | 2.82     |
# |    value_loss         | 5.52     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1400     |
# |    time_elapsed       | 205      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.00018  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1399     |
# |    policy_loss        | 3.13     |
# |    value_loss         | 5.83     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1500     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -15      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1499     |
# |    policy_loss        | 5.07     |
# |    value_loss         | 32.9     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | 162      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 1600     |
# |    time_elapsed       | 235      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 4.14e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.2      |
# |    value_loss         | 0.716    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 1700     |
# |    time_elapsed       | 250      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.35    |
# |    explained_variance | 9.87e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1699     |
# |    policy_loss        | 3.01     |
# |    value_loss         | 5.6      |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 225       |
# |    ep_rew_mean        | 162       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 1800      |
# |    time_elapsed       | 264       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -1.33     |
# |    explained_variance | -7.15e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 1799      |
# |    policy_loss        | 2.49      |
# |    value_loss         | 3.6       |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | 162      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 1900     |
# |    time_elapsed       | 279      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -0.00707 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1899     |
# |    policy_loss        | 2.75     |
# |    value_loss         | 5        |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 162      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2000     |
# |    time_elapsed       | 294      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0237   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1999     |
# |    policy_loss        | 2.66     |
# |    value_loss         | 4.57     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 225       |
# |    ep_rew_mean        | 163       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 2100      |
# |    time_elapsed       | 309       |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -1.29     |
# |    explained_variance | -6.91e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2099      |
# |    policy_loss        | 2.29      |
# |    value_loss         | 4.53      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 163      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2200     |
# |    time_elapsed       | 324      |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 1.55e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2199     |
# |    policy_loss        | 2.99     |
# |    value_loss         | 5        |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 164      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2300     |
# |    time_elapsed       | 338      |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 2.26e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2299     |
# |    policy_loss        | 1.53     |
# |    value_loss         | 3.89     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 165      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2400     |
# |    time_elapsed       | 353      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.0125   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2399     |
# |    policy_loss        | 2.53     |
# |    value_loss         | 4.52     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 225       |
# |    ep_rew_mean        | 165       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 2500      |
# |    time_elapsed       | 368       |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -1.28     |
# |    explained_variance | -2.05e-05 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2499      |
# |    policy_loss        | 0.457     |
# |    value_loss         | 0.516     |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 165      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2600     |
# |    time_elapsed       | 383      |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -6.75    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2599     |
# |    policy_loss        | 2.91     |
# |    value_loss         | 6.92     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 224       |
# |    ep_rew_mean        | 165       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 2700      |
# |    time_elapsed       | 398       |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -1.36     |
# |    explained_variance | -1.07e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2699      |
# |    policy_loss        | 2.69      |
# |    value_loss         | 5.05      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 165      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 2800     |
# |    time_elapsed       | 412      |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -0.00877 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2799     |
# |    policy_loss        | 2.27     |
# |    value_loss         | 4.36     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 224       |
# |    ep_rew_mean        | 166       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 2900      |
# |    time_elapsed       | 427       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.33     |
# |    explained_variance | -3.22e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2899      |
# |    policy_loss        | 2.42      |
# |    value_loss         | 4.21      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 223       |
# |    ep_rew_mean        | 166       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 3000      |
# |    time_elapsed       | 442       |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.35     |
# |    explained_variance | -3.46e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 2999      |
# |    policy_loss        | 2.37      |
# |    value_loss         | 4.02      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | 166      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3100     |
# |    time_elapsed       | 457      |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3099     |
# |    policy_loss        | 2.24     |
# |    value_loss         | 4.27     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 223       |
# |    ep_rew_mean        | 166       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 3200      |
# |    time_elapsed       | 472       |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.24     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3199      |
# |    policy_loss        | 1.15      |
# |    value_loss         | 1.33      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 222       |
# |    ep_rew_mean        | 166       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 3300      |
# |    time_elapsed       | 486       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | -2.74e-06 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3299      |
# |    policy_loss        | 2.36      |
# |    value_loss         | 3.38      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 166      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3400     |
# |    time_elapsed       | 501      |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -1.3     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3399     |
# |    policy_loss        | 2.93     |
# |    value_loss         | 3.95     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 166      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3500     |
# |    time_elapsed       | 515      |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.28    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3499     |
# |    policy_loss        | 2.34     |
# |    value_loss         | 4.49     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 167      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3600     |
# |    time_elapsed       | 529      |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3599     |
# |    policy_loss        | 2.53     |
# |    value_loss         | 2.96     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 221       |
# |    ep_rew_mean        | 167       |
# | time/                 |           |
# |    fps                | 33        |
# |    iterations         | 3700      |
# |    time_elapsed       | 544       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 3699      |
# |    policy_loss        | 1.09      |
# |    value_loss         | 1.39      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 167      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3800     |
# |    time_elapsed       | 559      |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.29    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3799     |
# |    policy_loss        | 2.12     |
# |    value_loss         | 3.71     |
# ------------------------------------
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 168      |
# | time/                 |          |
# |    fps                | 33       |
# |    iterations         | 3900     |
# |    time_elapsed       | 573      |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3899     |
# |    policy_loss        | 1.88     |
# |    value_loss         | 3.59     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | 168      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 4000     |
# |    time_elapsed       | 588      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | 3.28e-06 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.999    |
# |    value_loss         | 0.667    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 220      |
# |    ep_rew_mean        | 168      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 4100     |
# |    time_elapsed       | 602      |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4099     |
# |    policy_loss        | 2.66     |
# |    value_loss         | 3.87     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 220       |
# |    ep_rew_mean        | 168       |
# | time/                 |           |
# |    fps                | 20        |
# |    iterations         | 4200      |
# |    time_elapsed       | 1026      |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -0.649    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4199      |
# |    policy_loss        | 0.649     |
# |    value_loss         | 4.62      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 220       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 20        |
# |    iterations         | 4300      |
# |    time_elapsed       | 1040      |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -1.07     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.13      |
# |    value_loss         | 3.28      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 219       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 20        |
# |    iterations         | 4400      |
# |    time_elapsed       | 1055      |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -0.94     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4399      |
# |    policy_loss        | 1.87      |
# |    value_loss         | 1.53      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 4500     |
# |    time_elapsed       | 1069     |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4499     |
# |    policy_loss        | 1.87     |
# |    value_loss         | 3.15     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | 170      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 4600     |
# |    time_elapsed       | 1084     |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4599     |
# |    policy_loss        | 1.03     |
# |    value_loss         | 3.46     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 171      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 4700     |
# |    time_elapsed       | 1098     |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | -4.13    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4699     |
# |    policy_loss        | 2.01     |
# |    value_loss         | 2.72     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 171      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 4800     |
# |    time_elapsed       | 1113     |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.383   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4799     |
# |    policy_loss        | 1.54     |
# |    value_loss         | 2.12     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 171      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 4900     |
# |    time_elapsed       | 1127     |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -0.333   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.142    |
# |    value_loss         | 4.51     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 172      |
# | time/                 |          |
# |    fps                | 21       |
# |    iterations         | 5000     |
# |    time_elapsed       | 1142     |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4999     |
# |    policy_loss        | 1.98     |
# |    value_loss         | 3.8      |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 173      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5100     |
# |    time_elapsed       | 1156     |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -0.578   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.622    |
# |    value_loss         | 1.92     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 174      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5200     |
# |    time_elapsed       | 1172     |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5199     |
# |    policy_loss        | 1.61     |
# |    value_loss         | 3.05     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 174      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5300     |
# |    time_elapsed       | 1186     |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5299     |
# |    policy_loss        | 2.66     |
# |    value_loss         | 2.75     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 174      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5400     |
# |    time_elapsed       | 1202     |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.649   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.637    |
# |    value_loss         | 3.21     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | 175      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5500     |
# |    time_elapsed       | 1216     |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -0.651   |
# |    explained_variance | -2.92    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5499     |
# |    policy_loss        | 1.15     |
# |    value_loss         | 3.09     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | 175      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5600     |
# |    time_elapsed       | 1231     |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -0.229   |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.0814   |
# |    value_loss         | 3.99     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | 176      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5700     |
# |    time_elapsed       | 1246     |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5699     |
# |    policy_loss        | 1.37     |
# |    value_loss         | 2.47     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 176      |
# | time/                 |          |
# |    fps                | 22       |
# |    iterations         | 5800     |
# |    time_elapsed       | 1261     |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.431   |
# |    explained_variance | -6.49    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.604    |
# |    value_loss         | 2.09     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 176      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 5900     |
# |    time_elapsed       | 1275     |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.861   |
# |    explained_variance | -7.58    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5899     |
# |    policy_loss        | 0.961    |
# |    value_loss         | 3.18     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 177      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6000     |
# |    time_elapsed       | 1290     |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.17    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5999     |
# |    policy_loss        | 1.66     |
# |    value_loss         | 2.54     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 177      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6100     |
# |    time_elapsed       | 1305     |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.657   |
# |    explained_variance | -90      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6099     |
# |    policy_loss        | 1.93     |
# |    value_loss         | 8.19     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 177      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6200     |
# |    time_elapsed       | 1320     |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -0.98    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.999    |
# |    value_loss         | 2.29     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 215       |
# |    ep_rew_mean        | 178       |
# | time/                 |           |
# |    fps                | 23        |
# |    iterations         | 6300      |
# |    time_elapsed       | 1335      |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -0.194    |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 6299      |
# |    policy_loss        | 0.0609    |
# |    value_loss         | 3.51      |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6400     |
# |    time_elapsed       | 1350     |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -0.931   |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6399     |
# |    policy_loss        | 1.35     |
# |    value_loss         | 2.49     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6500     |
# |    time_elapsed       | 1365     |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.46    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6499     |
# |    policy_loss        | 1.05     |
# |    value_loss         | 0.938    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 23       |
# |    iterations         | 6600     |
# |    time_elapsed       | 1379     |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6599     |
# |    policy_loss        | 1.39     |
# |    value_loss         | 1.92     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 178      |
# | time/                 |          |
# |    fps                | 24       |
# |    iterations         | 6700     |
# |    time_elapsed       | 1394     |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -1.09    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6699     |
# |    policy_loss        | 1.17     |
# |    value_loss         | 2.05     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# ...
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 27800    |
# |    time_elapsed       | 4722     |
# |    total_timesteps    | 139000   |
# | train/                |          |
# |    entropy_loss       | -0.293   |
# |    explained_variance | -0.0585  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 27799    |
# |    policy_loss        | -0.169   |
# |    value_loss         | 0.413    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 27900    |
# |    time_elapsed       | 4737     |
# |    total_timesteps    | 139500   |
# | train/                |          |
# |    entropy_loss       | -0.189   |
# |    explained_variance | -0.00559 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 27899    |
# |    policy_loss        | 0.00466  |
# |    value_loss         | 0.00176  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28000    |
# |    time_elapsed       | 4751     |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -0.0752  |
# |    explained_variance | 0.000901 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 27999    |
# |    policy_loss        | 0.00297  |
# |    value_loss         | 0.0249   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28100    |
# |    time_elapsed       | 4766     |
# |    total_timesteps    | 140500   |
# | train/                |          |
# |    entropy_loss       | -0.0961  |
# |    explained_variance | -0.175   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28099    |
# |    policy_loss        | -0.0245  |
# |    value_loss         | 0.568    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28200    |
# |    time_elapsed       | 4780     |
# |    total_timesteps    | 141000   |
# | train/                |          |
# |    entropy_loss       | -0.0837  |
# |    explained_variance | 0.0156   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28199    |
# |    policy_loss        | 0.00376  |
# |    value_loss         | 0.0322   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28300    |
# |    time_elapsed       | 4795     |
# |    total_timesteps    | 141500   |
# | train/                |          |
# |    entropy_loss       | -0.174   |
# |    explained_variance | -0.138   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28299    |
# |    policy_loss        | -0.0873  |
# |    value_loss         | 0.497    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28400    |
# |    time_elapsed       | 4810     |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -0.224   |
# |    explained_variance | 0.0813   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28399    |
# |    policy_loss        | -0.00719 |
# |    value_loss         | 0.0199   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28500    |
# |    time_elapsed       | 4824     |
# |    total_timesteps    | 142500   |
# | train/                |          |
# |    entropy_loss       | -0.0153  |
# |    explained_variance | 5.96e-07 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28499    |
# |    policy_loss        | 7.71e-06 |
# |    value_loss         | 2.13e-05 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28600    |
# |    time_elapsed       | 4839     |
# |    total_timesteps    | 143000   |
# | train/                |          |
# |    entropy_loss       | -0.00147 |
# |    explained_variance | 5.75e-05 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28599    |
# |    policy_loss        | 3.12e-05 |
# |    value_loss         | 0.0692   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28700    |
# |    time_elapsed       | 4853     |
# |    total_timesteps    | 143500   |
# | train/                |          |
# |    entropy_loss       | -0.0336  |
# |    explained_variance | 0.00249  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28699    |
# |    policy_loss        | 0.000178 |
# |    value_loss         | 0.00161  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 209       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 28800     |
# |    time_elapsed       | 4868      |
# |    total_timesteps    | 144000    |
# | train/                |           |
# |    entropy_loss       | -0.00962  |
# |    explained_variance | 0.00384   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 28799     |
# |    policy_loss        | -9.96e-05 |
# |    value_loss         | 0.0111    |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 28900    |
# |    time_elapsed       | 4883     |
# |    total_timesteps    | 144500   |
# | train/                |          |
# |    entropy_loss       | -0.0164  |
# |    explained_variance | -0.00148 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28899    |
# |    policy_loss        | -0.00188 |
# |    value_loss         | 0.663    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29000    |
# |    time_elapsed       | 4898     |
# |    total_timesteps    | 145000   |
# | train/                |          |
# |    entropy_loss       | -0.342   |
# |    explained_variance | -0.121   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 28999    |
# |    policy_loss        | -0.117   |
# |    value_loss         | 0.438    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29100    |
# |    time_elapsed       | 4913     |
# |    total_timesteps    | 145500   |
# | train/                |          |
# |    entropy_loss       | -0.306   |
# |    explained_variance | 0.000289 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29099    |
# |    policy_loss        | -0.0172  |
# |    value_loss         | 0.00351  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29200    |
# |    time_elapsed       | 4928     |
# |    total_timesteps    | 146000   |
# | train/                |          |
# |    entropy_loss       | -0.0134  |
# |    explained_variance | 0.000671 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29199    |
# |    policy_loss        | 0.000201 |
# |    value_loss         | 0.0753   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29300    |
# |    time_elapsed       | 4942     |
# |    total_timesteps    | 146500   |
# | train/                |          |
# |    entropy_loss       | -0.259   |
# |    explained_variance | -0.0955  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29299    |
# |    policy_loss        | -0.155   |
# |    value_loss         | 0.473    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29400    |
# |    time_elapsed       | 4957     |
# |    total_timesteps    | 147000   |
# | train/                |          |
# |    entropy_loss       | -0.167   |
# |    explained_variance | -0.0351  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29399    |
# |    policy_loss        | -0.119   |
# |    value_loss         | 0.185    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 209       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 29500     |
# |    time_elapsed       | 4971      |
# |    total_timesteps    | 147500    |
# | train/                |           |
# |    entropy_loss       | -0.00663  |
# |    explained_variance | 0.0138    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 29499     |
# |    policy_loss        | -1.79e-05 |
# |    value_loss         | 0.00092   |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29600    |
# |    time_elapsed       | 4987     |
# |    total_timesteps    | 148000   |
# | train/                |          |
# |    entropy_loss       | -0.0451  |
# |    explained_variance | -0.00471 |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29599    |
# |    policy_loss        | 0.000122 |
# |    value_loss         | 0.000582 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29700    |
# |    time_elapsed       | 5001     |
# |    total_timesteps    | 148500   |
# | train/                |          |
# |    entropy_loss       | -0.0239  |
# |    explained_variance | 0.0489   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29699    |
# |    policy_loss        | -0.00381 |
# |    value_loss         | 0.657    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 182      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 29800    |
# |    time_elapsed       | 5016     |
# |    total_timesteps    | 149000   |
# | train/                |          |
# |    entropy_loss       | -0.376   |
# |    explained_variance | 0.00183  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 29799    |
# |    policy_loss        | -0.197   |
# |    value_loss         | 0.722    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 209       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 29900     |
# |    time_elapsed       | 5031      |
# |    total_timesteps    | 149500    |
# | train/                |           |
# |    entropy_loss       | -0.00779  |
# |    explained_variance | 0.048     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 29899     |
# |    policy_loss        | -1.06e-05 |
# |    value_loss         | 0.000329  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 208       |
# |    ep_rew_mean        | 182       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 30000     |
# |    time_elapsed       | 5046      |
# |    total_timesteps    | 150000    |
# | train/                |           |
# |    entropy_loss       | -0.0094   |
# |    explained_variance | -0.107    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 29999     |
# |    policy_loss        | -3.58e-06 |
# |    value_loss         | 3.16e-05  |
# -------------------------------------
# ✅ Training Complete.

# %%
def make_env_normalised():
    """
    Creates the base environment and applies the TimeLimit wrapper.
    """
    # Create the base env
    env = gym.make('gym4real/wds-v0', settings=base_params)
    return env

# %%
train_env = DummyVecEnv([make_env_normalised]) 
train_env = VecMonitor(train_env)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.)

MODEL_NAME = "DQN_WDSEnv_Normalise"

print("🧠 Initializing DQN Agent...")
model = DQN(
    "MlpPolicy", 
    train_env,
    device='cpu',
    verbose=1,
    tensorboard_log="./wds_logs/")

print(f"Training {MODEL_NAME}...")
model.learn(total_timesteps=150000, tb_log_name="dqn_wds_run_normalise") 
print("✅ Training Complete.")

# Save the model
model.save(MODEL_NAME)
# Out:
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# 🧠 Initializing DQN Agent...
# Using cpu device
# Training DQN_WDSEnv_Normalise...
# Resetting the environment...
# Logging to ./wds_logs/dqn_wds_run_normalise_1
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 34       |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 912      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00373  |
# |    n_updates        | 202      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 34       |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 1799     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00073  |
# |    n_updates        | 424      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 158      |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 34       |
# |    time_elapsed     | 78       |
# |    total_timesteps  | 2670     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000676 |
# |    n_updates        | 642      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 156      |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 34       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 3633     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000436 |
# |    n_updates        | 883      |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 160      |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 34       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 4505     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000174 |
# |    n_updates        | 1101     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 159      |
# |    exploration_rate | 0.661    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 34       |
# |    time_elapsed     | 157      |
# |    total_timesteps  | 5358     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 8.6e-05  |
# |    n_updates        | 1314     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 33       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 6288     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000111 |
# |    n_updates        | 1546     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: System may be hydraulically unstable.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 164      |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 33       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 7232     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 1782     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 33       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 8143     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.52e-05 |
# |    n_updates        | 2010     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 226      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 33       |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 9054     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.45e-05 |
# |    n_updates        | 2238     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 167      |
# |    exploration_rate | 0.373    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 33       |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 9906     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000103 |
# |    n_updates        | 2451     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.317    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 33       |
# |    time_elapsed     | 317      |
# |    total_timesteps  | 10788    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58e-05 |
# |    n_updates        | 2671     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 33       |
# |    time_elapsed     | 342      |
# |    total_timesteps  | 11630    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.35e-05 |
# |    n_updates        | 2882     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 170      |
# |    exploration_rate | 0.211    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 33       |
# |    time_elapsed     | 366      |
# |    total_timesteps  | 12454    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 6.89e-05 |
# |    n_updates        | 3088     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.157    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 33       |
# |    time_elapsed     | 391      |
# |    total_timesteps  | 13308    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.65e-05 |
# |    n_updates        | 3301     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.106    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 33       |
# |    time_elapsed     | 416      |
# |    total_timesteps  | 14120    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.18e-05 |
# |    n_updates        | 3504     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 171      |
# |    exploration_rate | 0.0527   |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 33       |
# |    time_elapsed     | 440      |
# |    total_timesteps  | 14957    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.25e-05 |
# |    n_updates        | 3714     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 33       |
# |    time_elapsed     | 464      |
# |    total_timesteps  | 15772    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.56e-05 |
# |    n_updates        | 3917     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 33       |
# |    time_elapsed     | 489      |
# |    total_timesteps  | 16606    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.56e-05 |
# |    n_updates        | 4126     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 33       |
# |    time_elapsed     | 514      |
# |    total_timesteps  | 17456    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.13e-05 |
# |    n_updates        | 4338     |
# ----------------------------------
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 33       |
# |    time_elapsed     | 541      |
# |    total_timesteps  | 18334    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.12e-05 |
# |    n_updates        | 4558     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 33       |
# |    time_elapsed     | 564      |
# |    total_timesteps  | 19144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.96e-05 |
# |    n_updates        | 4760     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 33       |
# |    time_elapsed     | 589      |
# |    total_timesteps  | 19988    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 4971     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 33       |
# |    time_elapsed     | 613      |
# |    total_timesteps  | 20792    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.26e-05 |
# |    n_updates        | 5172     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 174      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 33       |
# |    time_elapsed     | 636      |
# |    total_timesteps  | 21582    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.89e-05 |
# |    n_updates        | 5370     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 33       |
# |    time_elapsed     | 663      |
# |    total_timesteps  | 22494    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.1e-05  |
# |    n_updates        | 5598     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 33       |
# |    time_elapsed     | 689      |
# |    total_timesteps  | 23372    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.04e-05 |
# |    n_updates        | 5817     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 33       |
# |    time_elapsed     | 714      |
# |    total_timesteps  | 24222    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12e-05 |
# |    n_updates        | 6030     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 33       |
# |    time_elapsed     | 739      |
# |    total_timesteps  | 25095    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.02e-05 |
# |    n_updates        | 6248     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 33       |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 25917    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.12e-05 |
# |    n_updates        | 6454     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 33       |
# |    time_elapsed     | 791      |
# |    total_timesteps  | 26844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94e-05 |
# |    n_updates        | 6685     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 33       |
# |    time_elapsed     | 818      |
# |    total_timesteps  | 27751    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4e-05  |
# |    n_updates        | 6912     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 33       |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 28615    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.44e-05 |
# |    n_updates        | 7128     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 33       |
# |    time_elapsed     | 869      |
# |    total_timesteps  | 29485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.08e-05 |
# |    n_updates        | 7346     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 33       |
# |    time_elapsed     | 894      |
# |    total_timesteps  | 30324    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.93e-05 |
# |    n_updates        | 7555     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 213      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 33       |
# |    time_elapsed     | 921      |
# |    total_timesteps  | 31229    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00119  |
# |    n_updates        | 7782     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 33       |
# |    time_elapsed     | 949      |
# |    total_timesteps  | 32170    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.7e-05  |
# |    n_updates        | 8017     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 184      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 33       |
# |    time_elapsed     | 975      |
# |    total_timesteps  | 33013    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1e-05  |
# |    n_updates        | 8228     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 33       |
# |    time_elapsed     | 1001     |
# |    total_timesteps  | 33881    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.07e-05 |
# |    n_updates        | 8445     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 214      |
# |    ep_rew_mean      | 185      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 33       |
# |    time_elapsed     | 1025     |
# |    total_timesteps  | 34699    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.4e-05  |
# |    n_updates        | 8649     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 215      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 33       |
# |    time_elapsed     | 1051     |
# |    total_timesteps  | 35602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.17e-05 |
# |    n_updates        | 8875     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 216      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 33       |
# |    time_elapsed     | 1078     |
# |    total_timesteps  | 36537    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.73e-05 |
# |    n_updates        | 9109     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 217      |
# |    ep_rew_mean      | 187      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 33       |
# |    time_elapsed     | 1105     |
# |    total_timesteps  | 37452    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.02e-05 |
# |    n_updates        | 9337     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 33       |
# |    time_elapsed     | 1132     |
# |    total_timesteps  | 38383    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.31e-05 |
# |    n_updates        | 9570     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 33       |
# |    time_elapsed     | 1157     |
# |    total_timesteps  | 39273    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.87e-05 |
# |    n_updates        | 9793     |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 188      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 33       |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 40108    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.01e-05 |
# |    n_updates        | 10001    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 218      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 33       |
# |    time_elapsed     | 1207     |
# |    total_timesteps  | 40980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.84e-05 |
# |    n_updates        | 10219    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 219      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 33       |
# |    time_elapsed     | 1233     |
# |    total_timesteps  | 41890    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.75e-05 |
# |    n_updates        | 10447    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 33       |
# |    time_elapsed     | 1258     |
# |    total_timesteps  | 42754    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.61e-05 |
# |    n_updates        | 10663    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 33       |
# |    time_elapsed     | 1285     |
# |    total_timesteps  | 43676    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.55e-05 |
# |    n_updates        | 10893    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 33       |
# |    time_elapsed     | 1312     |
# |    total_timesteps  | 44624    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.96e-05 |
# |    n_updates        | 11130    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 34       |
# |    time_elapsed     | 1339     |
# |    total_timesteps  | 45540    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.28e-05 |
# |    n_updates        | 11359    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 34       |
# |    time_elapsed     | 1364     |
# |    total_timesteps  | 46437    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.83e-05 |
# |    n_updates        | 11584    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 34       |
# |    time_elapsed     | 1392     |
# |    total_timesteps  | 47390    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.97e-05 |
# |    n_updates        | 11822    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 34       |
# |    time_elapsed     | 1418     |
# |    total_timesteps  | 48285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.27e-05 |
# |    n_updates        | 12046    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 34       |
# |    time_elapsed     | 1445     |
# |    total_timesteps  | 49228    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.31e-05 |
# |    n_updates        | 12281    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 34       |
# |    time_elapsed     | 1469     |
# |    total_timesteps  | 50066    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000121 |
# |    n_updates        | 12491    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 34       |
# |    time_elapsed     | 1495     |
# |    total_timesteps  | 50981    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.3e-05  |
# |    n_updates        | 12720    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 34       |
# |    time_elapsed     | 1519     |
# |    total_timesteps  | 51781    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.07e-05 |
# |    n_updates        | 12920    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 34       |
# |    time_elapsed     | 1545     |
# |    total_timesteps  | 52678    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-05 |
# |    n_updates        | 13144    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 34       |
# |    time_elapsed     | 1569     |
# |    total_timesteps  | 53516    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.66e-05 |
# |    n_updates        | 13353    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 34       |
# |    time_elapsed     | 1594     |
# |    total_timesteps  | 54382    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.99e-05 |
# |    n_updates        | 13570    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 34       |
# |    time_elapsed     | 1618     |
# |    total_timesteps  | 55202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.61e-05 |
# |    n_updates        | 13775    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 34       |
# |    time_elapsed     | 1643     |
# |    total_timesteps  | 56071    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.48e-05 |
# |    n_updates        | 13992    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 223      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 34       |
# |    time_elapsed     | 1669     |
# |    total_timesteps  | 56980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.75e-05 |
# |    n_updates        | 14219    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 34       |
# |    time_elapsed     | 1694     |
# |    total_timesteps  | 57821    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.4e-05  |
# |    n_updates        | 14430    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 34       |
# |    time_elapsed     | 1719     |
# |    total_timesteps  | 58688    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.45e-05 |
# |    n_updates        | 14646    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 34       |
# |    time_elapsed     | 1743     |
# |    total_timesteps  | 59519    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.91e-05 |
# |    n_updates        | 14854    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 34       |
# |    time_elapsed     | 1769     |
# |    total_timesteps  | 60441    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.56e-06 |
# |    n_updates        | 15085    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 220      |
# |    ep_rew_mean      | 192      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 34       |
# |    time_elapsed     | 1795     |
# |    total_timesteps  | 61298    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.49e-05 |
# |    n_updates        | 15299    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 221      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 34       |
# |    time_elapsed     | 1823     |
# |    total_timesteps  | 62251    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.05e-05 |
# |    n_updates        | 15537    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 34       |
# |    time_elapsed     | 1849     |
# |    total_timesteps  | 63137    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.71e-05 |
# |    n_updates        | 15759    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 222      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 34       |
# |    time_elapsed     | 1875     |
# |    total_timesteps  | 64044    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.03e-05 |
# |    n_updates        | 15985    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# ...
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 197      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 34       |
# |    time_elapsed     | 3689     |
# |    total_timesteps  | 126495   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-05 |
# |    n_updates        | 31598    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 34       |
# |    time_elapsed     | 3713     |
# |    total_timesteps  | 127328   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.83e-05 |
# |    n_updates        | 31806    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 224      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 34       |
# |    time_elapsed     | 3737     |
# |    total_timesteps  | 128140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.32e-05 |
# |    n_updates        | 32009    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 34       |
# |    time_elapsed     | 3764     |
# |    total_timesteps  | 129060   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.19e-05 |
# |    n_updates        | 32239    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 34       |
# |    time_elapsed     | 3791     |
# |    total_timesteps  | 129999   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.77e-05 |
# |    n_updates        | 32474    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 225      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 34       |
# |    time_elapsed     | 3817     |
# |    total_timesteps  | 130878   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.39e-05 |
# |    n_updates        | 32694    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 34       |
# |    time_elapsed     | 3845     |
# |    total_timesteps  | 131828   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.32e-05 |
# |    n_updates        | 32931    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 199      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 34       |
# |    time_elapsed     | 3871     |
# |    total_timesteps  | 132734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94e-05 |
# |    n_updates        | 33158    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 34       |
# |    time_elapsed     | 3900     |
# |    total_timesteps  | 133712   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.95e-05 |
# |    n_updates        | 33402    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 34       |
# |    time_elapsed     | 3928     |
# |    total_timesteps  | 134660   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.62e-05 |
# |    n_updates        | 33639    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 34       |
# |    time_elapsed     | 3955     |
# |    total_timesteps  | 135587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.46e-05 |
# |    n_updates        | 33871    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 227      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 34       |
# |    time_elapsed     | 3979     |
# |    total_timesteps  | 136428   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.83e-06 |
# |    n_updates        | 34081    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 34       |
# |    time_elapsed     | 4009     |
# |    total_timesteps  | 137443   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.27e-05 |
# |    n_updates        | 34335    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 34       |
# |    time_elapsed     | 4037     |
# |    total_timesteps  | 138399   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.89e-05 |
# |    n_updates        | 34574    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 34       |
# |    time_elapsed     | 4065     |
# |    total_timesteps  | 139363   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.65e-05 |
# |    n_updates        | 34815    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 228      |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 34       |
# |    time_elapsed     | 4092     |
# |    total_timesteps  | 140276   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.82e-05 |
# |    n_updates        | 35043    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 229      |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 34       |
# |    time_elapsed     | 4122     |
# |    total_timesteps  | 141287   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.5e-05  |
# |    n_updates        | 35296    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 34       |
# |    time_elapsed     | 4151     |
# |    total_timesteps  | 142273   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.01e-05 |
# |    n_updates        | 35543    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 34       |
# |    time_elapsed     | 4176     |
# |    total_timesteps  | 143159   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.47e-05 |
# |    n_updates        | 35764    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 231      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 34       |
# |    time_elapsed     | 4206     |
# |    total_timesteps  | 144170   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.11e-05 |
# |    n_updates        | 36017    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 34       |
# |    time_elapsed     | 4235     |
# |    total_timesteps  | 145163   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.5e-05  |
# |    n_updates        | 36265    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 34       |
# |    time_elapsed     | 4266     |
# |    total_timesteps  | 146183   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.78e-05 |
# |    n_updates        | 36520    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 233      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 34       |
# |    time_elapsed     | 4293     |
# |    total_timesteps  | 147117   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.08e-05 |
# |    n_updates        | 36754    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 34       |
# |    time_elapsed     | 4323     |
# |    total_timesteps  | 148129   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.87e-05 |
# |    n_updates        | 37007    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 235      |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 34       |
# |    time_elapsed     | 4350     |
# |    total_timesteps  | 149059   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.02e-05 |
# |    n_updates        | 37239    |
# ----------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ✅ Training Complete.

# %%
train_env = DummyVecEnv([make_env_normalised]) 
train_env = VecMonitor(train_env)
train_env = VecNormalize(train_env, norm_obs=True, norm_reward=True, clip_obs=10.)

MODEL_NAME = "A2C_WDSEnv_Normalise"

# --- 4. TRAIN ---
print("🧠 Initializing A2C Agent...")
model = A2C(
    "MlpPolicy", 
    train_env, 
    learning_rate=1e-4,
    device="cpu", 
    verbose=1,
    tensorboard_log="./wds_logs/"
)

print(f"Training {MODEL_NAME}...")
model.learn(total_timesteps=200000, tb_log_name="a2c_wds_run_normalise") 
print("✅ Training Complete.")

model.save(MODEL_NAME)
# Out:
# 🧠 Initializing A2C Agent...
# Using cpu device
# Training A2C_WDSEnv_Normalise...
# Resetting the environment...
# Logging to ./wds_logs/a2c_wds_run_normalise_1
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /Users/kavish/miniforge3/envs/rl/lib/python3.10/site-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(
# Resetting the environment...
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 100      |
# |    time_elapsed       | 14       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -2.94    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 99       |
# |    policy_loss        | 0.293    |
# |    value_loss         | 0.0575   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 200      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.726    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.0537  |
# |    value_loss         | 0.00253  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 300      |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.815    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0507   |
# |    value_loss         | 0.00145  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 400      |
# |    time_elapsed       | 58       |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.464    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 399      |
# |    policy_loss        | 0.0441   |
# |    value_loss         | 0.00309  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 157      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 500      |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | -6.03    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.184   |
# |    value_loss         | 0.05     |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 600      |
# |    time_elapsed       | 87       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.451    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 599      |
# |    policy_loss        | 0.0455   |
# |    value_loss         | 0.00172  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 157      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 700      |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.39    |
# |    explained_variance | 0.652    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.00864 |
# |    value_loss         | 0.000343 |
# ------------------------------------
# /Users/kavish/Documents/gym4real/gym4real/envs/wds/simulator/epynet/epanet2.py:683: UserWarning: WARNING: Pumps cannot deliver enough flow or head.
#   warnings.warn(self.ENgeterror(ierr))
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 226      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 800      |
# |    time_elapsed       | 116      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -7.04    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.512    |
# |    value_loss         | 0.163    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 900      |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | -14.9    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0418   |
# |    value_loss         | 0.00236  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 154      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1000     |
# |    time_elapsed       | 145      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.38    |
# |    explained_variance | 0.581    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 999      |
# |    policy_loss        | -0.00824 |
# |    value_loss         | 0.00111  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1100     |
# |    time_elapsed       | 159      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | -73.3    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.231    |
# |    value_loss         | 0.0403   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1200     |
# |    time_elapsed       | 174      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.37    |
# |    explained_variance | 0.757    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.0108  |
# |    value_loss         | 0.000253 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 225      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1300     |
# |    time_elapsed       | 189      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.36    |
# |    explained_variance | -73.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.491    |
# |    value_loss         | 0.134    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1400     |
# |    time_elapsed       | 203      |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -1.34    |
# |    explained_variance | -31.9    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1399     |
# |    policy_loss        | 0.172    |
# |    value_loss         | 0.0236   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 223      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1500     |
# |    time_elapsed       | 218      |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.32    |
# |    explained_variance | -16.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1499     |
# |    policy_loss        | 0.106    |
# |    value_loss         | 0.0093   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 224      |
# |    ep_rew_mean        | 155      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1600     |
# |    time_elapsed       | 232      |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | -1.38    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.0996  |
# |    value_loss         | 0.0059   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 156      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1700     |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -0.152   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0546  |
# |    value_loss         | 0.00324  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 222      |
# |    ep_rew_mean        | 156      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1800     |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -22.4    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.0152  |
# |    value_loss         | 0.00898  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 221      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 1900     |
# |    time_elapsed       | 276      |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | -273     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1899     |
# |    policy_loss        | 0.141    |
# |    value_loss         | 0.092    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 219      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2000     |
# |    time_elapsed       | 290      |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.27    |
# |    explained_variance | -58.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.32     |
# |    value_loss         | 0.0461   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2100     |
# |    time_elapsed       | 305      |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.33    |
# |    explained_variance | -26.4    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.388   |
# |    value_loss         | 0.116    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2200     |
# |    time_elapsed       | 319      |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.19    |
# |    explained_variance | -55.6    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.091   |
# |    value_loss         | 0.0137   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2300     |
# |    time_elapsed       | 334      |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.31    |
# |    explained_variance | -274     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.347    |
# |    value_loss         | 0.107    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 218      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2400     |
# |    time_elapsed       | 348      |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.07    |
# |    explained_variance | -66.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0246   |
# |    value_loss         | 0.0196   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 217      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2500     |
# |    time_elapsed       | 363      |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | -6.43    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.162   |
# |    value_loss         | 0.025    |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2600     |
# |    time_elapsed       | 377      |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | -36      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.149    |
# |    value_loss         | 0.0183   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 216      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2700     |
# |    time_elapsed       | 392      |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | -28.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2699     |
# |    policy_loss        | -0.045   |
# |    value_loss         | 0.00793  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 215      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 34       |
# |    iterations         | 2800     |
# |    time_elapsed       | 406      |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0238  |
# |    value_loss         | 0.00143  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 214      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 2900     |
# |    time_elapsed       | 1081     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -26.9    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0281   |
# |    value_loss         | 0.00265  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 213      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 10       |
# |    iterations         | 3000     |
# |    time_elapsed       | 1372     |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -0.428   |
# |    explained_variance | -29.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00433  |
# |    value_loss         | 0.00742  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 212      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3100     |
# |    time_elapsed       | 1387     |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -1.21    |
# |    explained_variance | -18.5    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0374  |
# |    value_loss         | 0.0015   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3200     |
# |    time_elapsed       | 1401     |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -1.15    |
# |    explained_variance | -143     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3199     |
# |    policy_loss        | -0.124   |
# |    value_loss         | 0.0497   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 210      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3300     |
# |    time_elapsed       | 1416     |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | -5.65    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.0386  |
# |    value_loss         | 0.00072  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 209      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 11       |
# |    iterations         | 3400     |
# |    time_elapsed       | 1430     |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -107     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0433   |
# |    value_loss         | 0.00277  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 208      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3500     |
# |    time_elapsed       | 1445     |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -0.985   |
# |    explained_variance | -110     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0166   |
# |    value_loss         | 0.00533  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3600     |
# |    time_elapsed       | 1459     |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -1       |
# |    explained_variance | -86      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.127   |
# |    value_loss         | 0.00855  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 207      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3700     |
# |    time_elapsed       | 1473     |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -373     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0394   |
# |    value_loss         | 0.00463  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 206      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3800     |
# |    time_elapsed       | 1488     |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -1.18    |
# |    explained_variance | -706     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.0381   |
# |    value_loss         | 0.00196  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 205      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 12       |
# |    iterations         | 3900     |
# |    time_elapsed       | 1503     |
# |    total_timesteps    | 19500    |
# | train/                |          |
# |    entropy_loss       | -1.12    |
# |    explained_variance | -366     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3899     |
# |    policy_loss        | -0.0984  |
# |    value_loss         | 0.00968  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 205      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 4000     |
# |    time_elapsed       | 1519     |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -0.924   |
# |    explained_variance | -44.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.106   |
# |    value_loss         | 0.0149   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 204      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 4100     |
# |    time_elapsed       | 1534     |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -0.571   |
# |    explained_variance | -117     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0178  |
# |    value_loss         | 0.00966  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 203      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 4200     |
# |    time_elapsed       | 1548     |
# |    total_timesteps    | 21000    |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | -1.33    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0532  |
# |    value_loss         | 0.0232   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 202      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 4300     |
# |    time_elapsed       | 1564     |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -1.25    |
# |    explained_variance | -34.5    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.0701   |
# |    value_loss         | 0.00453  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 201      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 13       |
# |    iterations         | 4400     |
# |    time_elapsed       | 1578     |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | -8.13    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.0218   |
# |    value_loss         | 0.000608 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 14       |
# |    iterations         | 4500     |
# |    time_elapsed       | 1593     |
# |    total_timesteps    | 22500    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -881     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.0223   |
# |    value_loss         | 0.00134  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 199      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 14       |
# |    iterations         | 4600     |
# |    time_elapsed       | 1608     |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | -107     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0317   |
# |    value_loss         | 0.00203  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 198      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 14       |
# |    iterations         | 4700     |
# |    time_elapsed       | 1622     |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -0.848   |
# |    explained_variance | -36.6    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.0295  |
# |    value_loss         | 0.00109  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 197      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 14       |
# |    iterations         | 4800     |
# |    time_elapsed       | 1637     |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | -35.1    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.154   |
# |    value_loss         | 0.0107   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 195       |
# |    ep_rew_mean        | 160       |
# | time/                 |           |
# |    fps                | 14        |
# |    iterations         | 4900      |
# |    time_elapsed       | 1652      |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.11     |
# |    explained_variance | -2.28e+03 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 4899      |
# |    policy_loss        | 0.178     |
# |    value_loss         | 0.0335    |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 194      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 14       |
# |    iterations         | 5000     |
# |    time_elapsed       | 1667     |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -1.22    |
# |    explained_variance | -42.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 4999     |
# |    policy_loss        | -0.0322  |
# |    value_loss         | 0.00163  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 193      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5100     |
# |    time_elapsed       | 1682     |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -39.7    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.0315  |
# |    value_loss         | 0.00106  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 193      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5200     |
# |    time_elapsed       | 1697     |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -0.782   |
# |    explained_variance | -122     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0384   |
# |    value_loss         | 0.00922  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5300     |
# |    time_elapsed       | 1712     |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -0.511   |
# |    explained_variance | -5.39    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.0203   |
# |    value_loss         | 0.00147  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5400     |
# |    time_elapsed       | 1727     |
# |    total_timesteps    | 27000    |
# | train/                |          |
# |    entropy_loss       | -0.648   |
# |    explained_variance | -1.11    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.0122   |
# |    value_loss         | 0.00106  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | 161      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5500     |
# |    time_elapsed       | 1741     |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -41.2    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5499     |
# |    policy_loss        | 0.0188   |
# |    value_loss         | 0.000743 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 189      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 15       |
# |    iterations         | 5600     |
# |    time_elapsed       | 1756     |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -203     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5599     |
# |    policy_loss        | -0.00859 |
# |    value_loss         | 0.00241  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 189      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 5700     |
# |    time_elapsed       | 1770     |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -156     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5699     |
# |    policy_loss        | -0.00901 |
# |    value_loss         | 0.00131  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 189      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 5800     |
# |    time_elapsed       | 1785     |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -0.936   |
# |    explained_variance | -24.4    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.0477  |
# |    value_loss         | 0.00522  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 188      |
# |    ep_rew_mean        | 160      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 5900     |
# |    time_elapsed       | 1799     |
# |    total_timesteps    | 29500    |
# | train/                |          |
# |    entropy_loss       | -0.863   |
# |    explained_variance | -18.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.0486  |
# |    value_loss         | 0.00464  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 187      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 6000     |
# |    time_elapsed       | 1814     |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.05    |
# |    explained_variance | -164     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 5999     |
# |    policy_loss        | 0.0484   |
# |    value_loss         | 0.00252  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 187      |
# |    ep_rew_mean        | 159      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 6100     |
# |    time_elapsed       | 1829     |
# |    total_timesteps    | 30500    |
# | train/                |          |
# |    entropy_loss       | -0.931   |
# |    explained_variance | -88.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.0221  |
# |    value_loss         | 0.00112  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 6200     |
# |    time_elapsed       | 1843     |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -1.23    |
# |    explained_variance | -10.5    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.00148  |
# |    value_loss         | 0.000146 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 186      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 16       |
# |    iterations         | 6300     |
# |    time_elapsed       | 1858     |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -214     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.0216  |
# |    value_loss         | 0.00103  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 17       |
# |    iterations         | 6400     |
# |    time_elapsed       | 1873     |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.11    |
# |    explained_variance | -9.24    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0226  |
# |    value_loss         | 0.000475 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 17       |
# |    iterations         | 6500     |
# |    time_elapsed       | 1887     |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -0.639   |
# |    explained_variance | -7.73    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0278  |
# |    value_loss         | 0.00426  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 17       |
# |    iterations         | 6600     |
# |    time_elapsed       | 1902     |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -0.908   |
# |    explained_variance | -13.8    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0704  |
# |    value_loss         | 0.0141   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 185      |
# |    ep_rew_mean        | 158      |
# | time/                 |          |
# |    fps                | 17       |
# |    iterations         | 6700     |
# |    time_elapsed       | 1917     |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -1.1     |
# |    explained_variance | -217     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.0621   |
# |    value_loss         | 0.00442  |
# ...
# |    time_elapsed       | 6480     |
# |    total_timesteps    | 189000   |
# | train/                |          |
# |    entropy_loss       | -0.108   |
# |    explained_variance | -12.3    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 37799    |
# |    policy_loss        | -0.0352  |
# |    value_loss         | 0.00321  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 192      |
# |    ep_rew_mean        | 170      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 37900    |
# |    time_elapsed       | 6495     |
# |    total_timesteps    | 189500   |
# | train/                |          |
# |    entropy_loss       | -0.0695  |
# |    explained_variance | -13.1    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 37899    |
# |    policy_loss        | 0.000152 |
# |    value_loss         | 0.000541 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 170      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38000    |
# |    time_elapsed       | 6509     |
# |    total_timesteps    | 190000   |
# | train/                |          |
# |    entropy_loss       | -0.0628  |
# |    explained_variance | -16.4    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 37999    |
# |    policy_loss        | -0.00012 |
# |    value_loss         | 0.000167 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 38100     |
# |    time_elapsed       | 6524      |
# |    total_timesteps    | 190500    |
# | train/                |           |
# |    entropy_loss       | -0.0216   |
# |    explained_variance | -0.64     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 38099     |
# |    policy_loss        | -9.85e-06 |
# |    value_loss         | 2.45e-05  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 38200     |
# |    time_elapsed       | 6539      |
# |    total_timesteps    | 191000    |
# | train/                |           |
# |    entropy_loss       | -0.024    |
# |    explained_variance | -8.5      |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 38199     |
# |    policy_loss        | -1.88e-05 |
# |    value_loss         | 8.83e-05  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 38300     |
# |    time_elapsed       | 6554      |
# |    total_timesteps    | 191500    |
# | train/                |           |
# |    entropy_loss       | -0.271    |
# |    explained_variance | -5.71     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 38299     |
# |    policy_loss        | -0.000249 |
# |    value_loss         | 7.42e-05  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38400    |
# |    time_elapsed       | 6568     |
# |    total_timesteps    | 192000   |
# | train/                |          |
# |    entropy_loss       | -0.00639 |
# |    explained_variance | -5.4     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38399    |
# |    policy_loss        | 5.5e-06  |
# |    value_loss         | 0.000116 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38500    |
# |    time_elapsed       | 6583     |
# |    total_timesteps    | 192500   |
# | train/                |          |
# |    entropy_loss       | -0.0576  |
# |    explained_variance | -2.61    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38499    |
# |    policy_loss        | 0.000295 |
# |    value_loss         | 0.000634 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38600    |
# |    time_elapsed       | 6598     |
# |    total_timesteps    | 193000   |
# | train/                |          |
# |    entropy_loss       | -0.446   |
# |    explained_variance | -9.12    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38599    |
# |    policy_loss        | 0.0097   |
# |    value_loss         | 0.000749 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38700    |
# |    time_elapsed       | 6612     |
# |    total_timesteps    | 193500   |
# | train/                |          |
# |    entropy_loss       | -0.347   |
# |    explained_variance | -0.377   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38699    |
# |    policy_loss        | -0.015   |
# |    value_loss         | 0.0007   |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38800    |
# |    time_elapsed       | 6627     |
# |    total_timesteps    | 194000   |
# | train/                |          |
# |    entropy_loss       | -0.0834  |
# |    explained_variance | -8.48    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38799    |
# |    policy_loss        | 0.000665 |
# |    value_loss         | 0.000238 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 38900    |
# |    time_elapsed       | 6641     |
# |    total_timesteps    | 194500   |
# | train/                |          |
# |    entropy_loss       | -0.29    |
# |    explained_variance | -15.5    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38899    |
# |    policy_loss        | 0.000142 |
# |    value_loss         | 0.000112 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39000    |
# |    time_elapsed       | 6656     |
# |    total_timesteps    | 195000   |
# | train/                |          |
# |    entropy_loss       | -0.279   |
# |    explained_variance | -196     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 38999    |
# |    policy_loss        | -0.0127  |
# |    value_loss         | 0.00068  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 190      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39100    |
# |    time_elapsed       | 6671     |
# |    total_timesteps    | 195500   |
# | train/                |          |
# |    entropy_loss       | -0.438   |
# |    explained_variance | -37      |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39099    |
# |    policy_loss        | 0.0028   |
# |    value_loss         | 0.000286 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 39200     |
# |    time_elapsed       | 6685      |
# |    total_timesteps    | 196000    |
# | train/                |           |
# |    entropy_loss       | -0.00373  |
# |    explained_variance | -15.5     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 39199     |
# |    policy_loss        | -2.76e-06 |
# |    value_loss         | 0.000111  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39300    |
# |    time_elapsed       | 6700     |
# |    total_timesteps    | 196500   |
# | train/                |          |
# |    entropy_loss       | -0.215   |
# |    explained_variance | -5.92    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39299    |
# |    policy_loss        | 0.0169   |
# |    value_loss         | 0.000278 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39400    |
# |    time_elapsed       | 6715     |
# |    total_timesteps    | 197000   |
# | train/                |          |
# |    entropy_loss       | -0.309   |
# |    explained_variance | -8.56    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39399    |
# |    policy_loss        | 0.00151  |
# |    value_loss         | 0.000131 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 168      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39500    |
# |    time_elapsed       | 6729     |
# |    total_timesteps    | 197500   |
# | train/                |          |
# |    entropy_loss       | -0.134   |
# |    explained_variance | -6.08    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39499    |
# |    policy_loss        | 0.000108 |
# |    value_loss         | 0.000284 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39600    |
# |    time_elapsed       | 6744     |
# |    total_timesteps    | 198000   |
# | train/                |          |
# |    entropy_loss       | -0.126   |
# |    explained_variance | -5.86    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39599    |
# |    policy_loss        | 0.000692 |
# |    value_loss         | 0.000695 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39700    |
# |    time_elapsed       | 6759     |
# |    total_timesteps    | 198500   |
# | train/                |          |
# |    entropy_loss       | -0.0531  |
# |    explained_variance | 0.618    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39699    |
# |    policy_loss        | -6.1e-07 |
# |    value_loss         | 8.24e-06 |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 191       |
# |    ep_rew_mean        | 169       |
# | time/                 |           |
# |    fps                | 29        |
# |    iterations         | 39800     |
# |    time_elapsed       | 6773      |
# |    total_timesteps    | 199000    |
# | train/                |           |
# |    entropy_loss       | -0.0364   |
# |    explained_variance | -11.6     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 39799     |
# |    policy_loss        | -6.81e-05 |
# |    value_loss         | 0.000315  |
# -------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 39900    |
# |    time_elapsed       | 6788     |
# |    total_timesteps    | 199500   |
# | train/                |          |
# |    entropy_loss       | -0.248   |
# |    explained_variance | -0.33    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39899    |
# |    policy_loss        | 0.00302  |
# |    value_loss         | 0.00018  |
# ------------------------------------
# Resetting the environment...
# Resetting the environment...
# Resetting the environment...
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 191      |
# |    ep_rew_mean        | 169      |
# | time/                 |          |
# |    fps                | 29       |
# |    iterations         | 40000    |
# |    time_elapsed       | 6802     |
# |    total_timesteps    | 200000   |
# | train/                |          |
# |    entropy_loss       | -0.00288 |
# |    explained_variance | -85.9    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 39999    |
# |    policy_loss        | 1.12e-06 |
# |    value_loss         | 6.6e-05  |
# ------------------------------------
# ✅ Training Complete.
